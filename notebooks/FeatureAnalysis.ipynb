# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data = pd.read_csv("/home/ubuntu/ookla-statcan-analysis-neutron-1/data/hackathon/features_table.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Let's view the data
data.head()
# Out:
#     PRNAME CDTYPE CSDTYPE  SACTYPE CMATYPE  PCTYPE  PCCLASS  tests  devices
# 0  Ontario     RM       T        1       B     2.0      2.0     12        8  \
# 1  Ontario     RM       T        1       B     2.0      2.0     32        7
# 2  Ontario     RM       T        1       B     2.0      2.0      4        2
# 3  Ontario     RM       T        1       B     2.0      2.0    128       13
# 4  Ontario     RM       T        1       B     2.0      2.0      1        1
#
#        das_area      tile_area  tile_frac  das_frac  DAPOP  POP_DENSITY
# 0  4.489387e+06  205331.876525   0.917314  0.041955   1420   316.301553  \
# 1  5.391016e+06  205402.379648   0.894827  0.034094   1030   191.058601
# 2  1.030375e+07  205472.906899   0.611219  0.012189    505    49.011263
# 3  1.765704e+06  205472.906900   0.871430  0.101407    795   450.245236
# 4  5.391016e+06  205437.640257   0.939933  0.035818   1030   191.058601
#
#       avg_d_kbps     avg_u_kbps
# 0  201908.916667   23286.833333
# 1  393118.031250  169457.281250
# 2   19284.750000    4310.750000
# 3   10499.585938    1387.898438
# 4     535.000000     889.000000

# %%
#Show the data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338872 entries, 0 to 338871
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PRNAME       338872 non-null  object
#  1   CDTYPE       338872 non-null  object
#  2   CSDTYPE      338872 non-null  object
#  3   SACTYPE      338872 non-null  int64
#  4   CMATYPE      166387 non-null  object
#  5   PCTYPE       102046 non-null  float64
#  6   PCCLASS      102046 non-null  float64
#  7   tests        338872 non-null  int64
#  8   devices      338872 non-null  int64
#  9   das_area     338872 non-null  float64
#  10  tile_area    338872 non-null  float64
#  11  tile_frac    338872 non-null  float64
#  12  das_frac     338872 non-null  float64
#  13  DAPOP        338872 non-null  int64
#  14  POP_DENSITY  338872 non-null  float64
#  15  avg_d_kbps   338872 non-null  float64
#  16  avg_u_kbps   338872 non-null  float64
# dtypes: float64(9), int64(4), object(4)
# memory usage: 44.0+ MB

# %%
plotTarget = sns.displot(data=data, x= data.avg_u_kbps, hue=data.PCCLASS, multiple= 'stack').set(title="Average Upload Speed Based on Population Centre Class")
plotTarget.set_xticklabels(rotation=90)

# %%
plotTarget2 = sns.displot(data=data, x= data.avg_d_kbps, hue=data.PCCLASS, multiple= 'stack').set(title="Average Download Speed Based on Population Centre Class")

# %%
plotTarget3 = sns.displot(data=data, x= data.avg_u_kbps, hue=data.PRNAME, multiple= 'stack').set(title="Average Upload Speed Based on Province")
