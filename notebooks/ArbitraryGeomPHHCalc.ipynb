# %% [markdown]
# # Summary
# Generates the geojson hexes+dissolved cities file.
#
# Demonstrates calculation of 50/10 access levels from the NBD map data against arbitrary
# geometry other than the precomputed hexagons.
#
# Calculating this requires joining the geometry from the Canada wide hexagons geometry
# with the tabular `PHH_Speeds_Current-PHH_Vitesses_Actuelles.csv` dataset.
#
# Loading the data and executing the spatial joins takes a total of 7 minutes.

# %%
import sys
sys.path.append("..")

# %load_ext autoreload
# %autoreload 1
# %aimport src.datasets.joins
# %aimport src.datasets.loading.statcan
# Out:
# /Users/zacharyshand/.local/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from src.datasets.loading import statcan
from src.datasets.loading import ookla
from src.datasets import overlays

from src.datasets import joins
import src

# %%
popctrs = statcan.boundary('population_centres')

# %%
popctrs.loc[lambda s:s.PCNAME == "Lloydminster"]
# Out:
#     PCUID        PCNAME PCTYPE  PCPUID PCCLASS PRUID        PRNAME CMAUID  \
# 657  0478  Lloydminster      1  480478       3    48       Alberta    840
# 774  0478  Lloydminster      1  470478       3    47  Saskatchewan    840
#
#                                                CMANAME CMATYPE CMAPUID  \
# 657  Lloydminster (Alberta part / partie de l'Alberta)       D   48840
# 774  Lloydminster (Saskatchewan part / partie de la...       D   47840
#
#                                               geometry
# 657  POLYGON ((5024336.049 2072898.043, 5024239.789...
# 774  POLYGON ((5024135.374 2071102.100, 5024109.260...

# %%
custom_areas = joins.hexagons_small_popctrs_combined()
o = custom_areas
# Out:
# /Users/zacharyshand/ookla-statcan-analysis/notebooks/../src/datasets/overlays.py:25: UserWarning: `keep_geom_type=True` in overlay resulted in 418 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   ol = gp.overlay(left, right, how="union")
# /Users/zacharyshand/opt/anaconda3/envs/datascience/lib/python3.10/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
phh_speed_csv = src.config.DATA_DIRECTORY / 'PHH' / 'CRTC_Speed_Data' / 'PHH_Speeds_Current-PHH_Vitesses_Actuelles.csv'
phh_speeds = pd.read_csv(phh_speed_csv)

phh_geo = statcan.phh_geometry()

phh = phh_geo.merge(phh_speeds, on='PHH_ID')
phh = phh.merge(statcan.phh_data(), on='PHH_ID')
phh = phh.loc[lambda s:s.Type !=8] # drop PHH nulls

# %%
o = joins.add_phh_pop(custom_areas, phh, 'HEXUID_PCPUID')

# %%
del o['HEXuid_HEXidu'] # we don't want these, they're quite long in large cities

# %%
popctrs = statcan.boundary('population_centres') # use this to generate a filtering region around cities

# %%
#Can't plot the whole country, too many hexagons.
xmin, ymin, xmax, ymax = popctrs.loc[lambda s:s.PCNAME=="Lloydminster"].buffer(100000).total_bounds
o.cx[xmin:xmax,ymin:ymax].loc[lambda s:(s['Pop2016'] > 0) | (s['TDwell2016_TLog2016'] > 0) | (s['URDwell2016_RH2016']>0)].explore('Pop_Avail_50_10',  scheme='equalinterval', k = 4,)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_defe6d958a2b34c2357f9955d904f37a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_defe6d958a2b34c2357f9955d904f37a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_defe6d958a2b34c2357f9955d904f37a = L.map(
#                 &quot;map_defe6d958a2b34c2357f9955d904f37a&quot;,
#                 {
#                     center: [53.26775526965031, -110.05961585787924],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_defe6d958a2b34c2357f9955d904f37a);
#
#
#
#
#
#             var tile_layer_060e9d6138d4b0bf437ddf72a63249ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_defe6d958a2b34c2357f9955d904f37a);
#
#
#             map_defe6d958a2b34c2357f9955d904f37a.fitBounds(
#                 [[52.06022951438961, -112.05890120872216], [54.475281024911, -108.06033050703633]],
#                 {}
#             );
#
#
#         function geo_json_55e3847812b401a163e97327edd92dc6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;701&quot;: case &quot;709&quot;: case &quot;719&quot;: case &quot;733&quot;: case &quot;742&quot;: case &quot;781&quot;: case &quot;801&quot;: case &quot;810&quot;: case &quot;813&quot;: case &quot;408377&quot;: case &quot;408523&quot;: case &quot;408902&quot;: case &quot;409067&quot;: case &quot;409080&quot;: case &quot;409152&quot;: case &quot;409267&quot;: case &quot;409389&quot;: case &quot;409418&quot;: case &quot;409419&quot;: case &quot;411641&quot;: case &quot;411686&quot;: case &quot;412487&quot;: case &quot;412505&quot;: case &quot;412543&quot;: case &quot;412600&quot;: case &quot;412658&quot;: case &quot;412673&quot;: case &quot;412683&quot;: case &quot;412712&quot;: case &quot;412768&quot;: case &quot;412771&quot;: case &quot;412849&quot;: case &quot;415321&quot;: case &quot;415433&quot;: case &quot;415480&quot;: case &quot;415519&quot;: case &quot;415533&quot;: case &quot;415583&quot;: case &quot;415584&quot;: case &quot;415643&quot;: case &quot;415694&quot;: case &quot;415855&quot;: case &quot;415883&quot;: case &quot;415977&quot;: case &quot;419239&quot;: case &quot;419283&quot;: case &quot;419294&quot;: case &quot;419356&quot;: case &quot;419394&quot;: case &quot;419531&quot;: case &quot;419597&quot;: case &quot;419655&quot;: case &quot;419700&quot;: case &quot;419702&quot;: case &quot;423493&quot;: case &quot;423604&quot;: case &quot;423626&quot;: case &quot;423659&quot;: case &quot;423680&quot;: case &quot;423681&quot;: case &quot;423800&quot;: case &quot;423855&quot;: case &quot;426448&quot;: case &quot;426515&quot;: case &quot;426682&quot;: case &quot;426997&quot;: case &quot;426998&quot;: case &quot;427026&quot;: case &quot;427163&quot;: case &quot;427181&quot;: case &quot;427220&quot;: case &quot;427298&quot;: case &quot;428813&quot;: case &quot;428872&quot;: case &quot;428920&quot;: case &quot;428966&quot;: case &quot;429018&quot;: case &quot;429231&quot;: case &quot;429343&quot;: case &quot;429430&quot;: case &quot;430587&quot;: case &quot;430604&quot;: case &quot;430606&quot;: case &quot;430623&quot;: case &quot;430634&quot;: case &quot;430654&quot;: case &quot;430663&quot;: case &quot;453441&quot;: case &quot;453442&quot;: case &quot;453506&quot;: case &quot;453644&quot;: case &quot;453669&quot;: case &quot;456657&quot;: case &quot;456741&quot;: case &quot;456873&quot;: case &quot;456887&quot;: case &quot;456936&quot;: case &quot;457529&quot;: case &quot;457551&quot;: case &quot;457552&quot;: case &quot;457684&quot;: case &quot;457761&quot;: case &quot;460775&quot;: case &quot;460873&quot;: case &quot;460874&quot;: case &quot;460939&quot;: case &quot;460940&quot;: case &quot;461008&quot;: case &quot;461077&quot;: case &quot;461080&quot;: case &quot;461781&quot;: case &quot;461782&quot;: case &quot;465270&quot;: case &quot;465271&quot;: case &quot;465272&quot;: case &quot;465286&quot;: case &quot;465317&quot;: case &quot;465318&quot;: case &quot;465345&quot;: case &quot;465472&quot;: case &quot;465564&quot;: case &quo

# %%
zeroable_cols = [
    'Pop2016', 'TDwell2016_TLog2016', 'URDwell2016_RH2016',
    'Pop2016_at_50_10_Combined', 'TDwell2016_at_50_10_Combined',
    'URDwell_at_50_10_Combined'
       ]
o[zeroable_cols] = o[zeroable_cols].fillna(0)

# %%
o
# Out:
#         PCPUID       pc_area      hex_area  \
# 55      100792  1.719773e+08  2.539316e+07
# 56      100792  1.719773e+08  2.539316e+07
# 57      100792  1.719773e+08  2.536795e+07
# 58      100792  1.719773e+08  2.542434e+07
# 59      100792  1.719773e+08  2.540903e+07
# ...        ...           ...           ...
# 519965     NaN           NaN  2.441105e+07
# 519966     NaN           NaN  2.447289e+07
# 519967     NaN           NaN  2.450451e+07
# 519968     NaN           NaN  2.444205e+07
# 519969     NaN           NaN  2.438113e+07
#
#                                                  geometry  hex_frac   pc_frac  \
# 55      MULTIPOLYGON (((8975148.894 2149398.714, 89753...  0.440441  0.065033
# 56      POLYGON ((8967674.386 2143964.411, 8967679.029...  0.514429  0.075958
# 57      POLYGON ((8971687.209 2162844.838, 8971644.644...  0.000288  0.000043
# 58      POLYGON ((8983681.000 2140410.863, 8983745.474...  0.043914  0.006492
# 59      POLYGON ((8979409.323 2142110.794, 8979381.251...  0.619943  0.091594
# ...                                                   ...       ...       ...
# 519965  POLYGON ((4391568.918 2319505.032, 4389028.114...  1.000000       NaN
# 519966  POLYGON ((4370293.149 2275226.474, 4367751.202...  1.000000       NaN
# 519967  POLYGON ((4359727.416 2253237.353, 4357184.726...  1.000000       NaN
# 519968  POLYGON ((4380906.610 2297314.924, 4378365.292...  1.000000       NaN
# 519969  POLYGON ((4402281.048 2341798.831, 4399740.647...  1.000000       NaN
#
#             HEXUID_PCPUID PRCODE      PCNAME PCCLASS  ...  \
# 55      NL47580528-100792     NL  St. John's       4  ...
# 56      NL47580529-100792     NL  St. John's       4  ...
# 57      NL47710527-100792     NL  St. John's       4  ...
# 58      NL47430528-100792     NL  St. John's       4  ...
# 59      NL47510528-100792     NL  St. John's       4  ...
# ...                   ...    ...         ...     ...  ...
# 519965         BC53331204     BC         NaN     NaN  ...
# 519966         BC52891204     BC         NaN     NaN  ...
# 519967         BC52661204     BC         NaN     NaN  ...
# 519968         BC53111204     BC         NaN     NaN  ...
# 519969         BC53561204     BC         NaN     NaN  ...
#
#         TDwell2016_TLog2016  URDwell2016_RH2016  PHH_Count  Common_Type  \
# 55              5058.332094         4318.056742      685.0          3.0
# 56              1648.265873         1558.259524      437.0          4.0
# 57                 0.000000            0.000000        NaN          NaN
# 58              1056.284918         1025.692964      149.0          3.0
# 59             10449.110393         9692.839561     1684.0          3.0
# ...                     ...                 ...        ...          ...
# 519965             0.000000            0.000000        1.0          1.0
# 519966             0.000000            0.000000        NaN          NaN
# 519967             0.000000            0.000000        NaN          NaN
# 519968             0.000000            0.000000        NaN          NaN
# 519969             0.000000            0.000000        NaN          NaN
#
#         Pop2016_at_50_10_Combined  TDwell2016_at_50_10_Combined  \
# 55                    9860.925340                   5043.554316
# 56                    4252.819048                   1648.265873
# 57                       0.000000                      0.000000
# 58                    2662.527342                   1056.284918
# 59                   24029.650382                  10449.110393
# ...                           ...                           ...
# 519965                   0.000000                      0.000000
# 519966                   0.000000                      0.000000
# 519967                   0.000000                      0.000000
# 519968                   0.000000                      0.000000
# 519969                   0.000000                      0.000000
#
#         URDwell_at_50_10_Combined  Pop_Avail_50_10  TDwell_Avail_50_10  \
# 55                    4304.723408        99.644081           99.707853
# 56                    1558.259524       100.000000          100.000000
# 57                       0.000000              NaN                 NaN
# 58                    1025.692964       100.000000          100.000000
# 59                    9692.839561       100.000000          100.000000
# ...                           ...              ...                 ...
# 519965                   0.000000              NaN                 NaN
# 519966                   0.000000              NaN                 NaN
# 519967                   0.000000              NaN                 NaN
# 519968                   0.000000              NaN                 NaN
# 519969                   0.000000              NaN                 NaN
#
#         URDwell_Avail_50_10
# 55                99.691219
# 56               100.000000
# 57                      NaN
# 58               100.000000
# 59               100.000000
# ...                     ...
# 519965                  NaN
# 519966                  NaN
# 519967                  NaN
# 519968                  NaN
# 519969                  NaN
#
# [518095 rows x 21 columns]

# %%
from pathlib import Path
from src import config

# %%
derived_geometry = (Path(src.config.DATA_DIRECTORY) / 'processed' / 'geometries').resolve()
derived_geometry.mkdir(exist_ok=True, parents=True)

o.to_crs("EPSG:4326").to_file(derived_geometry / 'hexagons_w_dissolved_smaller_popctrs.geojson', driver='GeoJSON')

# %%
o.to_file(derived_geometry / 'hexagons_w_dissolved_smaller_popctrs', driver="MapInfo File")
